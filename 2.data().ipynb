# %% [markdown]
# ## 데이터 입출력

# %%
import pandas as pd
import numpy as np

# %%
# CSV 파일을 리스트로 저장
# ex 14-13
import population as pop

list_data = []
pop.get_list(list_data)
list_data
# Out:
# [['서울특별시  (1100000000)',
#   '부산광역시  (2600000000)',
#   '대구광역시  (2700000000)',
#   '인천광역시  (2800000000)',
#   '광주광역시  (2900000000)',
#   '대전광역시  (3000000000)',
#   '울산광역시  (3100000000)',
#   '세종특별자치시  (3600000000)',
#   '경기도  (4100000000)',
#   '강원도  (4200000000)',
#   '충청북도  (4300000000)',
#   '충청남도  (4400000000)',
#   '전라북도  (4500000000)',
#   '전라남도  (4600000000)',
#   '경상북도  (4700000000)',
#   '경상남도  (4800000000)',
#   '제주특별자치도  (5000000000)'],
#  ['9,736,962',
#   '3,410,925',
#   '2,432,883',
#   '2,954,955',
#   '1,456,121',
#   '1,473,125',
#   '1,145,710',
#   '343,788',
#   '13,265,377',
#   '1,539,521',
#   '1,598,599',
#   '2,120,995',
#   '1,815,112',
#   '1,861,894',
#   '2,658,956',
#   '3,358,828',
#   '670,876'],
#  ['4,345,877',
#   '1,502,333',
#   '1,033,349',
#   '1,242,107',
#   '618,503',
#   '637,726',
#   '469,551',
#   '136,629',
#   '5,497,087',
#   '721,003',
#   '723,931',
#   '961,890',
#   '818,452',
#   '873,871',
#   '1,229,265',
#   '1,455,655',
# ...

# %%
np.array(list_data)
# Out:
# array([['서울특별시  (1100000000)', '부산광역시  (2600000000)',
#         '대구광역시  (2700000000)', '인천광역시  (2800000000)',
#         '광주광역시  (2900000000)', '대전광역시  (3000000000)',
#         '울산광역시  (3100000000)', '세종특별자치시  (3600000000)',
#         '경기도  (4100000000)', '강원도  (4200000000)', '충청북도  (4300000000)',
#         '충청남도  (4400000000)', '전라북도  (4500000000)', '전라남도  (4600000000)',
#         '경상북도  (4700000000)', '경상남도  (4800000000)',
#         '제주특별자치도  (5000000000)'],
#        ['9,736,962', '3,410,925', '2,432,883', '2,954,955', '1,456,121',
#         '1,473,125', '1,145,710', '343,788', '13,265,377', '1,539,521',
#         '1,598,599', '2,120,995', '1,815,112', '1,861,894', '2,658,956',
#         '3,358,828', '670,876'],
#        ['4,345,877', '1,502,333', '1,033,349', '1,242,107', '618,503',
#         '637,726', '469,551', '136,629', '5,497,087', '721,003',
#         '723,931', '961,890', '818,452', '873,871', '1,229,265',
#         '1,455,655', '293,932'],
# ...
