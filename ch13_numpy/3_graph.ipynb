# %% [markdown]
# ## 데이터프레임 시각화

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib as mpl
mpl.rcParams['axes.unicode_minus'] = False
mpl.rc('font', family = 'Malgun Gothic')
font1 = {'size': 18, 'color': 'green'}

# %%
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# ### Seaborn 패키지 이용한 그래프

# %%
import seaborn as sns

# %%
iris = sns.load_dataset('iris')
titanic = sns.load_dataset('titanic')
tips = sns.load_dataset('tips')
flights = sns.load_dataset('flights')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.shape
# Out:
# (150, 5)

# %%
titanic.shape
# Out:
# (891, 15)

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %% [markdown]
# ### - 1차원 실수 분포 플롯

# %%
x = iris.petal_length.values

sns.rugplot(x)

# %%
sns.distplot(x, kde = True, rug = True)

# %% [markdown]
# ### - 카운트 플롯

# %%
sns.countplot(x = 'class', data = titanic)

# %%
titanic['class'].value_counts()
# Out:
# Third     491
# First     216
# Second    184
# Name: class, dtype: int64

# %%
sns.countplot(x = 'day', data = tips)

# %% [markdown]
# ## 2차원 실수형 데이터
#
# ### - 산점도 (jointplot)

# %%
sns.jointplot(x = 'sepal_length', y = 'sepal_width', data = iris)

# %%
plt.scatter(iris['sepal_length'], iris['sepal_width'])

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris, hue = 'species')

# %% [markdown]
# ### - 2차원 카테고리 데이터(Heatmap)

# %%
titanic_size = titanic.pivot_table(
    index = 'class', columns = 'sex', aggfunc = 'size')
titanic_size
# Out:
# sex     female  male
# class
# First       94   122
# Second      76   108
# Third      144   347

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.heatmap(titanic_size, cmap = sns.light_palette('gray', as_cmap = True), annot= True, fmt = 'd')

# %% [markdown]
# ## 2차원 복합 데이터
#
# ### - Bar plot

# %%
sns.barplot(x = 'day', y = 'total_bill', data = tips)

# %%
sns.boxplot(x = 'day', y = 'total_bill', data = tips)

# %%
iris[:5].plot.bar(rot = 0)

# %%
df3 = titanic.pclass.value_counts()
df3.plot.pie(autopct = '%.2f%%')

# %%
iris.boxplot(by = 'species')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024048844148>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000240480E3408>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024048F1B508>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002404893F1C8>]],
#       dtype=object)
